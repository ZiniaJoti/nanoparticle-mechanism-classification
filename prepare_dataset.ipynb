# %%
import pandas as pd

df1 = pd.read_csv("data/labeled/abstracts_labeled_1000.csv")
df2 = pd.read_csv("data/labeled/abstracts_labeled_2000.csv")
df3 = pd.read_csv("data/labeled/wrapping_labeled_1000.csv")

df = pd.concat([df1, df2, df3], ignore_index=True)
df.to_csv("data/labeled/final_dataset.csv", index=False)
